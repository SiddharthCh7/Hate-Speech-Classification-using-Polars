# %%
import polars as pl

# %%
df = pl.read_csv("HateSpeechDatasetBalanced.csv")
df = df.unique()
df.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ Content                         ┆ Label │
# │ ---                             ┆ ---   │
# │ str                             ┆ i64   │
# ╞═════════════════════════════════╪═══════╡
# │ still shove that little barn r… ┆ 1     │
# │ the guy next to me just said t… ┆ 0     │
# │ tell everyone i have zero hatr… ┆ 0     │
# │ okay thanks for writing an awe… ┆ 0     │
# │ so happy as to not be born hom… ┆ 1     │
# └─────────────────────────────────┴───────┘

# %%
text = df.with_columns(pl.col('Content').str.to_lowercase())

type(text)
# Out:
# polars.dataframe.frame.DataFrame

# %%
import polars as pl
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from typing import List
import time

stop_words = set(stopwords.words('english'))
exception_words = {'no', 'not', 'never'}
filtered_stopwords = stop_words - exception_words
lemmatizer = WordNetLemmatizer()
def lemmatize_word(text):
    return [lemmatizer.lemmatize(word, pos="v") for word in text]

def remove_stopwords(text: str):
    return [word for word in text if word not in filtered_stopwords]


def preprocess(df: pl.DataFrame) -> pl.DataFrame:
    start = time.time()
    xdf = df.lazy().with_columns(pl.col("Content").str.to_lowercase().alias("Content").str.split(by=' ').alias("Tokens_Content"))

    xdf = xdf.with_columns(
        pl.col("Tokens_Content").map_elements(
            lambda batch: [
                lemmatizer.lemmatize(word, pos="v") 
                for word in batch 
                if word not in filtered_stopwords and not word.isdigit()
            ],
            return_dtype=pl.List(pl.Utf8)
        ).alias("Processed_Content")).collect()
    end = time.time()
    print(f"Time taken : {(end-start):.3f}")
    return xdf

# %%
processed_df = preprocess(df)
# Out:
# Time taken : 163.409

# %%
sentences = processed_df['Processed_Content'].to_list()
sentences
# Out:
# [['still',
#   'shove',
#   'little',
#   'barn',
#   'rock',
#   'star',
#   'straight',
#   'ass',
#   'faggot'],
#  ['guy', 'next', 'say', 'jews', 'turn', 'soap', 'wtf'],
#  ['tell',
#   'everyone',
#   'zero',
#   'hatred',
#   'toward',
#   'muslims',
#   'shame',
#   'think',
#   'lie'],
#  ['okay',
#   'thank',
#   'write',
#   'awesome',
#   'article',
#   'really',
#   'impress',
#   'do',
#   'finish',
#   'read',
#   'change',
#   'couple',
#   'minor',
#   'grammatical',
#   'word',
#   'things',
#   'leave',
#   'detail',
#   'edit',
#   'summaries',
#   'check',
#   'edit',
#   'make',
#   'sure',
#   'not',
#   'wreck',
#   'anything',
#   'happy',
#   'promote',
#   'article',
#   'congratulations',
#   'advance'],
#  ['happy', 'not', 'bear', 'homosexual'],
#  ['jako',
#   'normal',
#   'political',
#   'medicine',
#   'overdose',
#   'nas',
#   'svi',
#   'make',
#   'idiot',
#   'niece'],
#  ['young', 'buck', 'want', 'eat', 'nigguh', 'like', 'not', 'fuck'],
#  ['thetrapdoor',
#   'org',
#   'revert',
#   'link',
#   'slut',
#   'remove',
#   'another',
#   'editor',
#   'recently',
#   'little',
#   'spam',
#   'clean',
#   'recently',
#   'anyway',
#   'previous',
#   'message',
#   'old',
#   'username',
#   'advise',
#   'address',
#   'talk',
#   'trap',
#   'door',
#   'wait',
#   'comment',
#   'one',
#   'week',
#   'message',
#   'slut',
#   'leave',
#   'internet',
#   'protocol',
#   'previously',
#   'use',
#   'add',
#   'article',
#   'anyway',
#   'week',
#   'later',
#   'blank',
#   'message',
#   'article',
#   'talk',
#   'page',
#   'reason',
#   'not',
#   'revert',
#   'edit',
#   'despite',
#   'notice',
#   'fact',
#   'no',
#   'one',
#   'approve',
#   'link',
#   'time',
#   'slut',
#   'not',
#   'care',
#   'much',
#   'important',
#   'things',
#   'forget',
#   'nearly',
#   'six',
#   'months',
#   'view',
#   'site',
#   'seem',
#   'little',
#   'info',
#   'encyclopedic',
#   'worth',
#   'mean',
#   'heck',
#   'cartoon',
#   'even',
#   'interview',
#   'creators',
#   'one',
#   'last',
#   'thing',
#   'wikipedia',
#   'not',
#   'practice',
#   'idea',
#   'reciprocation',
#   'link',
#   'us',
#   'win',
#   'no',
#   'point',
#   'talk'],
#  ['help',
#   'dear',
#   'tina',
#   'think',
#   'need',
#   'help',
#   'please',
#   'stop',
#   'upload',
#   'image',
#   'try',
#   'contact',
#   'establish',
#   'editor',
#   'need',
#   'upload',
#   'happy',
#   'help',
#   'wasp',
#   'doc'],
#  ['around', 'world', 'gotta', 'find', 'whatever', 'number', 'people', 'black'],
#  ['thank',
#   'cowboy',
#   'get',
#   'back',
#   'write',
#   'study',
#   'worth',
#   'effort',
#   'read'],
#  ['coolies', 'doom', 'us'],
#  ['retweet',
#   'equal',
#   'non',
#   'sexist',
#   'anything',
#   'wow',
#   'women',
#   'cray',
#   'time',
#   'haha'],
#  ['throw',
#   'race',
#   'forget',
#   'happen',
#   'white',
#   'women',
#   'accuse',
#   'bill',
#   'clinton',
#   'sexual',
#   'allegations',
#   'liberal',
#   'democrats',
#   'rally',
#   'around',
#   'liberals',
#   'disgust',
#   'disgraceful',
#   'human',
#   'beings',
#   'god',
#   'create'],
#  ['not', 'make', 'change', 'article', 'toupees', 'not', 'public', 'computer'],
#  ['twice',
#   'twitter',
#   'restrict',
#   'say',
#   'fuck',
#   'bitch',
#   'go',
#   'vagina',
#   'account',
#   'block',
#   'ps',
#   'youtube',
#   'glue'],
#  ['father', 'day', 'father', 'make', 'happen', 'salute'],
#  ['male', 'king', 'angola'],
#  ['retweet',
#   'four',
#   'brothers',
#   'show',
#   'bitch',
#   'lot',
#   'niggas',
#   'would',
#   'kill',
#   'would',
#   'kill',
#   'victor',
#   'sweet',
#   'slut',
#   'one',
#   'l'],
#  ['america',
#   'need',
#   'create',
#   'laws',
#   'revoke',
#   'citizenship',
#   'legal',
#   'immigrants',
#   'break',
#   'laws',
#   'whatever',
#   'need',
#   'restore',
#   'demographics',
#   'america'],
#  ['jesus', 'fuck', 'christ'],
#  ['regard',
#   'edit',
#   'make',
#   'utc',
#   'thank',
#   'experiment',
#   'wikipedia',
#   'test',
#   'work',
#   'revert',
#   'remove',
#   'please',
#   'use',
#   'sandbox',
#   'test',
#   'want',
#   'take',
#   'look',
#   'welcome',
#   'page',
#   'would',
#   'like',
#   'learn',
#   'contribute',
#   'encyclopedia'],
#  ['public', 'domain', 'reinstate', 'image'],
#  ['lowkey',
#   'get',
#   'fan',
#   'hoop',
#   'skills',
#   'lbc',
#   'aha',
#   'niggah',
#   'laugh',
#   'loud'],
#  ['question',
#   'wrong',
#   'lso',
#   'link',
#   'keep',
#   'remove',
#   'mark',
#   'spam',
#   'seem',
#   'like',
#   'perfectly',
#   'acceptable',
#   'link'],
#  ['time',
#   'minute',
#   'elvis',
#   'creeper',
#   'dude',
#   'like',
#   'grab',
#   'danger',
#   'fuck',
#   'man',
#   'teacher',
#   'say',
#   'bus',
#   'slut',
#   'fine',
#   'fuck',
#   'son',
#   'bitch',
#   'columbus',
#   'ben',
#   'franklin',
#   'worth',
#   'die',
#   'kill',
#   'not',
#   'stay',
#   'okay',
#   'laugh',
#   'loud',
#   'hey',
#   'richie',
#   'hi',
#   'itsdamageinc',
#   'think',
#   'macho',
#   'man',
#   'whoa',
#   'whoa',
#   'oh',
#   'god',
#   'know',
#   'right',
#   'guy',
#   'yeah',
#   'exactly',
#   'rock',
#   'though',
#   'love',
#   'song',
#   'best',
#   'scene',
#   'trailer',
#   'guy',
#   'put',
#   'shark',
#   'lake',
#   'songs',
#   'video',
#   'call'],
#  ['lithium',
#   'salt',
#   'please',
#   'notice',
#   'lithium',
#   'salt',
#   'already',
#   'direct',
#   'lithium',
#   'salt',
#   'disambiguation',
#   'page',
#   'suppose',
#   'term',
#   'drug',
#   'briticism',
#   'actually',
#   'lithium',
#   'salt',
#   'many',
#   'chemical',
#   'meanings',
#   'stay',
#   'disambiguation',
#   'page',
#   'please',
#   'not',
#   'redirect'],
#  ['mother',
#   'fuck',
#   'lucky',
#   'wander',
#   'around',
#   'delete',
#   'photos',
#   'x',
#   'problem'],
#  ['grand',
#   'slam',
#   'not',
#   'think',
#   'grand',
#   'slam',
#   'refer',
#   'current',
#   'slam',
#   'current',
#   'players',
#   'not',
#   'reflect',
#   'list',
#   'point',
#   'creation'],
#  ['happy',
#   'johnmccainday',
#   'also',
#   'fuck',
#   'trump',
#   'impeach',
#   'trump',
#   'impeachdonaldtrump'],
#  ['look',
#   'forward',
#   'long',
#   'drag',
#   'onto',
#   'issue',
#   'yesterday',
#   'new',
#   'press',
#   'organization',
#   'hire',
#   'antifa',
#   'code'],
#  ['let',
#   'know',
#   'please',
#   'let',
#   'know',
#   'go',
#   'harsh',
#   'pass',
#   'negative',
#   'comment',
#   'upon',
#   'discuss',
#   'deletion',
#   'salem',
#   'abdullah',
#   'khan',
#   'please',
#   'let',
#   'know'],
#  ['donald', 'trump', 'ruin', 'everything'],
#  ['actually',
#   'not',
#   'mess',
#   'anything',
#   'read',
#   'closely',
#   'say',
#   'solomon',
#   'islands',
#   'fifth',
#   'nation',
#   'recognize',
#   'independence',
#   'abkhazia',
#   'south',
#   'ossetia',
#   'not',
#   'know',
#   'get',
#   'kind',
#   'source',
#   'not',
#   'find',
#   'anyway',
#   'still',
#   'however',
#   'recommend',
#   'people',
#   'continue',
#   'find',
#   'source',
#   'neverless',
#   'doubt',
#   'true'],
#  ['game', 'row', 'join', 'progress', 'fuck', 'vagina'],
#  ['vandalise',
#   'ok',
#   'last',
#   'time',
#   'shag',
#   'mean',
#   'mr',
#   'encyclopaedia',
#   'non',
#   'possess',
#   'wikipedia',
#   'loser',
#   'english',
#   'twat',
#   'hey',
#   'not',
#   'contribute',
#   'substance',
#   'describe',
#   'get',
#   'life'],
#  ['bizarre',
#   'story',
#   'charge',
#   'formally',
#   'glad',
#   'streets',
#   'certainly',
#   'concern',
#   'clueless',
#   'cop',
#   'like',
#   'protect',
#   'us'],
#  ['not', 'rocket', 'science', 'haha', 'mistake'],
#  ['wmf',
#   'not',
#   'hold',
#   'list',
#   'people',
#   'postal',
#   'address',
#   'need',
#   'contact',
#   'people',
#   'order',
#   'send',
#   'shirt',
#   'time',
#   'wmf',
#   'contact',
#   'dr',
#   'blood',
#   'either',
#   'dr',
#   'blood',
#   'might',
#   'edit',
#   'not',
#   'could',
#   'choose',
#   'whether',
#   'decline',
#   'shirt',
#   'time',
#   'no',
#   'possibility',
#   'shirt',
#   'somehow',
#   'lose',
#   'waste',
#   'blood',
#   'volcano'],
#  ['arrrggghhhh',
#   'absolutely',
#   'rag',
#   'momma',
#   'guilt',
#   'trip',
#   'year',
#   'old',
#   'boy',
#   'spend',
#   'time',
#   'girlfriend',
#   'wash',
#   'give',
#   'one',
#   'one',
#   'time',
#   'absolutely',
#   'livid',
#   'father',
#   'twat',
#   'dickhead',
#   'face',
#   'symbols',
#   'mouth',
#   'face',
#   'jaw',
#   'symbols',
#   'write',
#   'mouth',
#   'face',
#   'jaw',
#   'little',
#   'symbols',
#   'mouth',
#   'face',
#   'symbols',
#   'lower',
#   'mouth'],
#  ['already', 'unblock'],
#  ['would', 'lie', 'say', 'like', 'african', 'people'],
#  ['tell', 'look', 'second', 'one', 'rather', 'large'],
#  ['get',
#   'ready',
#   'eat',
#   'two',
#   'sega',
#   'breakfast',
#   'lunch',
#   'dinner',
#   'bad',
#   'fuck',
#   'go',
#   'put',
#   'hard',
#   'foot',
#   'ass',
#   'bitch'],
#  ['no',
#   'one',
#   'like',
#   'fuck',
#   'rude',
#   'wastefulness',
#   'good',
#   'sperm',
#   'cell'],
#  ['hey', 'new', 'would', 'like', 'someone', 'talk', 'hit', 'back', 'whatever'],
#  ['refugee', 'ruin', 'british', 'civilization'],
#  ['suck',
#   'suck',
#   'gordon',
#   'even',
#   'admins',
#   'check',
#   'users',
#   'discover',
#   'ips',
#   'block',
#   'long',
#   'periods',
#   'time',
#   'whatever',
#   'press',
#   'reset',
#   'button',
#   'modems',
#   'within',
#   'minutes',
#   'whatever',
#   'would',
#   'get',
#   'new',
#   'internet',
#   'protocol',
#   'able',
#   'vandalise',
#   'result',
#   'hope',
#   'admins',
#   'realize',
#   'block',
#   'useless',
#   'indeed',
#   'always',
#   'get',
#   'block',
#   'save',
#   'time',
#   'yet',
#   'another',
#   'check',
#   'user',
#   'internet',
#   'protocol',
#   'use',
#   'case',
#   'hold',
#   'non',
#   'figure',
#   'previously',
#   'use',
#   'internet',
#   'protocol',
#   'see',
#   'slut',
#   'block',
#   'months',
#   'yesterday',
#   'useless',
#   'block',
#   'quite',
#   'easy',
#   'circumvent'],
#  ['calabasas', 'california', 'avoid', 'use', 'puffer', 'article', 'thank'],
#  ['news',
#   'hi',
#   'say',
#   'go',
#   'somalia',
#   'right',
#   'apart',
#   'foundation',
#   'unite',
#   'somali',
#   'parliamentarians',
#   'support',
#   'pm',
#   'anything',
#   'go',
#   'forward',
#   'border',
#   'change',
#   'maker',
#   'punt',
#   'land',
#   'somaliland',
#   'thank'],
#  ['example', 'chichi', 'base', 'leon', 'bloodhound', 'lolwut'],
#  ['thank', 'good', 'work', 'slut', 'recognize'],
#  ['hence',
#   'plaguy',
#   'excuse',
#   'reason',
#   'dislike',
#   'soldiery',
#   'everyone',
#   'already',
#   'cognizant',
#   'obvious',
#   'explanations',
#   'feel',
#   'common',
#   'sentiency'],
#  ['like', 'lunch', 'little', 'man'],
#  ['check',
#   'brand',
#   'uk',
#   'hey',
#   'get',
#   'zoloft',
#   'one',
#   'ban',
#   'wikipediocracy',
#   'use',
#   'say',
#   'die',
#   'well',
#   'mean',
#   'dead',
#   'recover',
#   'mean',
#   'die',
#   'not',
#   'not',
#   'want',
#   'die',
#   'monetary',
#   'increase',
#   'meet',
#   'maker',
#   'check'],
#  ['ilegal',
#   'idiot',
#   'make',
#   'law',
#   'threaten',
#   'industry',
#   'alien',
#   'baptist',
#   'baptist',
#   'bunch',
#   'morons'],
#  ['indians',
#   'definitely',
#   'not',
#   'ever',
#   'allow',
#   'time',
#   'speak',
#   'anymore',
#   'dialect',
#   'suck'],
#  ['rape', 'stick', 'finger', 'booty', 'hole', 'sleep'],
#  ['notability', 'stimulant', 'report'],
#  ['mention', 'dog', 'not', 'deserve', 'separate', 'link', 'ok', 'utc'],
#  ['mary',
#   'bi',
#   'happen',
#   'sve',
#   'italy',
#   'zanijemila',
#   'bih',
#   'previse',
#   'tupoglavosti',
#   'primitivism',
#   'ja',
#   'no',
#   'idea',
#   'gleam',
#   'saki',
#   'dan',
#   'fb',
#   'vest',
#   'hr',
#   'shut',
#   'katastrofalne',
#   'vrime',
#   'brno',
#   'leti',
#   'uk',
#   'go',
#   'ahead',
#   'je',
#   'manlike',
#   'presence',
#   'na',
#   'evo',
#   'sad',
#   'non',
#   'applicable',
#   'severe',
#   'holstein',
#   'kod',
#   'mark',
#   'martine',
#   'supra',
#   'see',
#   'graham',
#   'di',
#   'ti',
#   'pozdrav',
#   'overdose',
#   'nas',
#   'svi'],
#  ['non', 'fault', 'adult', 'female', 'ignorant'],
#  ['show',
#   'even',
#   'single',
#   'case',
#   'open',
#   'antifa',
#   'actually',
#   'murder',
#   'someone',
#   'english',
#   'far',
#   'right',
#   'government',
#   'murder',
#   'someone',
#   'charlottesville',
#   'person',
#   'shrug',
#   'hypocrisy',
#   'work',
#   'ways'],
#  ['anal', 'sex', 'gallery', 'human', 'sex'],
#  ['would', 'rather', 'get', 'coronavirus', 'near', 'sikh'],
#  ['go', 'thank', 'spot'],
#  ['q',
#   'information',
#   'technology',
#   'okay',
#   'call',
#   'jesus',
#   'course',
#   'information',
#   'technology',
#   'thumb',
#   'improve'],
#  ['not', 'touch', 'greek', 'page', 'not', 'want', 'touch'],
#  ['article',
#   'hi',
#   'crystal',
#   'ways',
#   'show',
#   'permission',
#   'share',
#   'text',
#   'us',
#   'press',
#   'issue',
#   'article',
#   'please',
#   'read',
#   'advice',
#   'write',
#   'autobiographies',
#   'carefully',
#   'major',
#   'difference',
#   'promote',
#   'write',
#   'encyclopedia',
#   'article',
#   'submission',
#   'fall',
#   'rather',
#   'clearly',
#   'first',
#   'category',
#   'include',
#   'independent',
#   'reliable',
#   'source',
#   'article',
#   'crucial',
#   'whatever',
#   'guidelines',
#   'explain',
#   'typically',
#   'make',
#   'artists',
#   'worthy',
#   'include',
#   'wikipedia',
#   'please',
#   'let',
#   'us',
#   'know',
#   'question',
#   'talk'],
#  ['email', 'send'],
#  ['retweet',
#   'every',
#   'bitch',
#   'get',
#   'nigga',
#   'go',
#   'always',
#   'fuck',
#   'no',
#   'matter',
#   'heart',
#   'arrow'],
#  ['respond',
#   'request',
#   'think',
#   'one',
#   'much',
#   'improve',
#   'article',
#   'could',
#   'improve',
#   'even',
#   'would',
#   'would',
#   'consider',
#   'provide',
#   'source',
#   'throughout',
#   'example',
#   'albany',
#   'become',
#   'vegetarian',
#   'would',
#   'lbs',
#   'follow',
#   'health',
#   'scare',
#   'later',
#   'suffer',
#   'heart',
#   'attack',
#   'quickly',
#   'recover',
#   'two',
#   'sentence',
#   'could',
#   'use',
#   'form',
#   'reference',
#   'verification',
#   'might',
#   'want',
#   'look',
#   'article',
#   'example',
#   'reference',
#   'great',
#   'work',
#   'thus',
#   'far'],
#  ['go',
#   'insist',
#   'would',
#   'suggest',
#   'merge',
#   'article',
#   'western',
#   'roman',
#   'empire',
#   'start',
#   'new',
#   'article',
#   'actual',
#   'roman',
#   'empire',
#   'course',
#   'entire',
#   'history',
#   'rather',
#   'part',
#   'cherry',
#   'pick',
#   'relevance',
#   'western',
#   'countries'],
#  ['bernie',
#   'sanders',
#   'delete',
#   'first',
#   'ask',
#   'later',
#   'hmmm',
#   'hurt',
#   'much',
#   'later',
#   'ex',
#   'kid',
#   'girl',
#   'age',
#   'not',
#   'former',
#   'wife',
#   'quit',
#   'fuck',
#   'edit',
#   'no',
#   'liberal',
#   'kook'],
#  ['retweet',
#   'like',
#   'honestly',
#   'know',
#   'women',
#   'espn',
#   'also',
#   'happen',
#   'sexiest'],
#  ['mozzie', 'men', 'beard'],
#  ['ought',
#   'air',
#   'minute',
#   'episodes',
#   'disney',
#   'channel',
#   'american',
#   'address',
#   'u',
#   'word',
#   'canadian',
#   'person'],
#  ['bill', 'v', 'trump'],
#  ['not',
#   'illegal',
#   'unless',
#   'prove',
#   'chuck',
#   'orrises',
#   'bike',
#   'could',
#   'biggest',
#   'fear',
#   'comment',
#   'not',
#   'get',
#   'post',
#   'least',
#   'calm',
#   'sir',
#   'calm',
#   'guy',
#   'gay',
#   'unsubbed',
#   'sell',
#   'nice',
#   'wonderful',
#   'useless',
#   'turd',
#   'talk',
#   'eye',
#   'spouse',
#   'two',
#   'hundred',
#   'twenty',
#   'two',
#   'thousand',
#   'two',
#   'hundred',
#   'twenty',
#   'two',
#   'get',
#   'oh',
#   'believe',
#   'afford',
#   'box',
#   'non',
#   'first',
#   'rag',
#   'like',
#   'professional',
#   'experience',
#   'always',
#   'throw',
#   'racist',
#   'card',
#   'speak',
#   'mind',
#   'correct',
#   'freedom',
#   'speech',
#   'not',
#   'make',
#   'threats',
#   'anything',
#   'nature',
#   'not',
#   'insult',
#   'black',
#   'man',
#   'black',
#   'man',
#   'insult',
#   'not',
#   'touch',
#   'every',
#   'black',
#   'globe',
#   'go',
#   'experience',
#   'not',
#   'illiterate',
#   'slut',
#   'illiterate',
#   'would',
#   'not',
#   'able',
#   'speak',
#   'type',
#   'fail',
#   'troll',
#   'make',
#   'false',
#   'accusations',
#   'express',
#   'opinion',
#   'fail',
#   'troll',
#   'frown',
#   'sad',
#   'andy',
#   'pout',
#   'niggas',
#   'lie',
#   'videos',
#   'get',
#   'old',
#   'mean',
#   'look',
#   'maya',
#   'lay',
#   'damn',
#   'see',
#   'better',
#   'p',
#   'cameras',
#   'better',
#   'laugh',
#   'ass',
#   'no',
#   'problem',
#   'oea',
#   'wutdahellisdisshet',
#   'not',
#   'worry',
#   'whatever',
#   'not',
#   'invade',
#   'shit',
#   'hole',
#   'house',
#   'much',
#   'would',
#   'cost',
#   'together'],
#  ['not',
#   'sopranos',
#   'episode',
#   'one',
#   'christopher',
#   'go',
#   'new',
#   'york',
#   'pitch',
#   'script',
#   'see',
#   'janine',
#   'set',
#   'movie',
#   'shoot',
#   'think',
#   'would',
#   'check',
#   'see',
#   'exactly',
#   'episode',
#   'etc',
#   'lazy',
#   'write',
#   'enough',
#   'burden'],
#  ['hahahahahahaah',
#   'lake',
#   'see',
#   'profit',
#   'pamela',
#   'police',
#   'sega',
#   'eu',
#   'bold',
#   'za',
#   'ono',
#   'sto',
#   'je',
#   'bill',
#   'shut',
#   'podivljali',
#   'pro',
#   'not',
#   'applicable',
#   'basket',
#   'upatou',
#   'job',
#   'njemacka',
#   'happen',
#   'moreno',
#   'oval',
#   'muslim',
#   'pamela',
#   'java'],
#  ['think', 'funny', 'take', 'death', 'unify', 'people'],
#  ['marriage', 'not', 'kid'],
#  ['also',
#   'not',
#   'quotation',
#   'mark',
#   'around',
#   'since',
#   'simply',
#   'chemical',
#   'compound',
#   'not',
#   'anywhere',
#   'dubious'],
#  ['think',
#   'winter',
#   'think',
#   'winter',
#   'eurasia',
#   'force',
#   'black',
#   'people',
#   'start',
#   'slut',
#   'expect',
#   'survive',
#   'anywhere',
#   'else',
#   'show',
#   'seed',
#   'rise',
#   'dead',
#   'word',
#   'death',
#   'not',
#   'end',
#   'unfortunately'],
#  ['cannot',
#   'believe',
#   'superior',
#   'us',
#   'white',
#   'look',
#   'become',
#   'like',
#   'us'],
#  ['bridge',
#   'sure',
#   'bridge',
#   'within',
#   'city',
#   'regardless',
#   'parish',
#   'boundaries',
#   'would',
#   'say',
#   'bridge',
#   'outside',
#   'city',
#   'overlook',
#   'hilton',
#   'east',
#   'well',
#   'outside',
#   'city',
#   'bob'],
#  ['onto',
#   'promote',
#   'elimination',
#   'animals',
#   'love',
#   'people',
#   'not',
#   'animals',
#   'smirk',
#   'smirk'],
#  ['fat', 'lot', 'good', 'medieval', 'history', 'degree', 'days'],
#  ['not',
#   'think',
#   'necessary',
#   'list',
#   'tea',
#   'party',
#   'politicians',
#   'article',
#   'anyway',
#   'ron',
#   'paul',
#   'already',
#   'list',
#   'table',
#   'ron',
#   'paul',
#   'article',
#   'appropriate',
#   'lead',
#   'properly',
#   'source'],
#  ['threshold',
#   'true',
#   'let',
#   'print',
#   'clump',
#   'lie',
#   'stomp',
#   'anyone',
#   'dare',
#   'offer',
#   'alternate',
#   'opinion',
#   'mean',
#   'nerveless',
#   'k',
#   'good',
#   'enough',
#   'abc',
#   'domain',
#   'intelligence',
#   'tonight',
#   'not',
#   'lot',
#   'let',
#   'us',
#   'verify',
#   'information',
#   'base',
#   'statements',
#   'make',
#   'morons',
#   'totally',
#   'ignorant',
#   'field',
#   'work',
#   'call',
#   'squat',
#   'fake',
#   'yet',
#   'nothing',
#   'buddy',
#   'shameful',
#   'tycoon',
#   'hungry',
#   'little',
#   'people',
#   'no',
#   'live'],
#  ['nice', 'video', 'look', 'like', 'use', 'animator'],
#  ['us',
#   'talk',
#   'japanese',
#   'attitudes',
#   'like',
#   'japanese',
#   'people',
#   'honesty'],
#  ['go',
#   'pick',
#   'star',
#   'pokemonsunmoon',
#   'hype',
#   'star',
#   'nerd',
#   'gen',
#   'seven'],
#  ['retweet',
#   'want',
#   'stay',
#   'competition',
#   'whatever',
#   'not',
#   'finish',
#   'tell',
#   'everyone',
#   'pretty',
#   'whatever',
#   'mr'],
#  ['stfu',
#   'dirty',
#   'ugly',
#   'wet',
#   'musty',
#   'hair',
#   'dirty',
#   'ass',
#   'wetback',
#   'swear',
#   'cannot',
#   'stand',
#   'dirty',
#   'ugly',
#   'pale',
#   'girl',
#   'face',
#   'wannabe',
#   'white',
#   'spics',
#   'post',
#   'racist',
#   'hate',
#   'bullshit',
#   'shh',
#   'get',
#   'least',
#   'dislike',
#   'group',
#   'people',
#   'america',
#   'spit',
#   'shit',
#   'next',
#   'cute',
#   'little',
#   'wetback',
#   'kid',
#   'face',
#   'see',
#   'u'],
#  ['hence',
#   'not',
#   'opinion',
#   'racism',
#   'extend',
#   'people',
#   'base',
#   'race',
#   'justify',
#   'prejudice',
#   'open',
#   'stop',
#   'racism'],
#  ['white',
#   'black',
#   'mean',
#   'cool',
#   'k',
#   'nigger',
#   'fuck',
#   'know',
#   'fuck',
#   'real',
#   'niggers',
#   'dead',
#   'end'],
#  ['list',
#   'political',
#   'slur',
#   'almost',
#   'lack',
#   'enough',
#   'cojones',
#   'guess',
#   'gotta',
#   'wish',
#   'like',
#   'great',
#   'slut',
#   'quick',
#   'next',
#   'get',
#   'second',
#   'administrator',
#   'opinion',
#   'know',
#   'pair',
#   'green',
#   'eye',
#   'saw',
#   'say',
#   'speedy',
#   'sucker',
#   'get',
#   'thank'],
#  ['disability', 'abnormal'],
#  ['foreigners', 'dislike', 'violence'],
#  ['lav',
#   'hire',
#   'whore',
#   'breed',
#   'dummy',
#   'golf',
#   'hole',
#   'contraband',
#   'pander',
#   'white',
#   'bitch',
#   'spade',
#   'suit',
#   'clothe',
#   'smirk',
#   'look'],
#  ['mentally',
#   'ill',
#   'congo',
#   'number',
#   'one',
#   'amongst',
#   'ill',
#   'fan',
#   'stalkers',
#   'laura',
#   'kellogg',
#   'fun',
#   'follow',
#   'around',
#   'post',
#   'obsessive',
#   'get',
#   'help',
#   'anyone',
#   'proceed',
#   'someone',
#   'look',
#   'conduct',
#   'sociopath',
#   'like',
#   'claim',
#   'enjoy',
#   'follow',
#   'people',
#   'around',
#   'good',
#   'luck',
#   'get',
#   'help'],
#  ['behavior',
#   'fight',
#   'back',
#   'aggressive',
#   'serialize',
#   'invasions',
#   'stop',
#   'assail',
#   'pine',
#   'tree',
#   'state'],
#  ['muslims', 'love', 'rap'],
#  ['kate',
#   'gun',
#   'safety',
#   'minor',
#   'code',
#   'sound',
#   'cool',
#   'cool',
#   'gun',
#   'control',
#   'not',
#   'anything',
#   'safe',
#   'gun',
#   'control',
#   'strict',
#   'limit',
#   'law',
#   'abide',
#   'ignore',
#   'laws',
#   'wake',
#   'ya',
#   'folks',
#   'mn',
#   'need',
#   'get',
#   'liberal',
#   'wagon',
#   'vote',
#   'german',
#   'patriots',
#   'little',
#   'red',
#   'latin',
#   'crossstatue',
#   'libertylocomotiveanchorflag',
#   'unite',
#   'state'],
#  ['go',
#   'santa',
#   'not',
#   'black',
#   'cannot',
#   'black',
#   'historically',
#   'yeah',
#   'macy',
#   'coca',
#   'cola',
#   'characterization',
#   'fine',
#   'white'],
#  ['sexually', 'trans', 'adults', 'abhorrent'],
#  ['love', 'white', 'glad', 'really', 'not', 'ever', 'ape'],
#  ['right',
#   'understand',
#   'actually',
#   'not',
#   'realize',
#   'slut',
#   'main',
#   'page',
#   'probably',
#   'would',
#   'wait',
#   'slut',
#   'take',
#   'follow',
#   'specific',
#   'request',
#   'not',
#   'tell',
#   'slut',
#   'deal',
#   'dye',
#   'whatever'],
#  ['fuck',
#   'sake',
#   'washington',
#   'redskins',
#   'cleveland',
#   'indians',
#   'consider',
#   'change',
#   'name',
#   'fuck',
#   'care'],
#  ['retweet',
#   'oh',
#   'snap',
#   'world',
#   'countries',
#   'think',
#   'people',
#   'like',
#   'questionsformen',
#   'http'],
#  ['zasto', 'je', 'delozacija', 'jesus'],
#  ['enter',
#   'illegal',
#   'alien',
#   'use',
#   'model',
#   'create',
#   'bay',
#   'area',
#   'politicians',
#   'like',
#   'repl'],
#  ['shithole',
#   'countries',
#   'around',
#   'slut',
#   'opinion',
#   'think',
#   'people',
#   'might',
#   'thoughtful'],
#  ['remove',
#   'section',
#   'unit',
#   'history',
#   'entire',
#   'section',
#   'head',
#   'theater',
#   'sustain',
#   'lift',
#   'verbatim',
#   'site',
#   'absence',
#   'explanation',
#   'must',
#   'consider',
#   'copyright',
#   'violation',
#   'remove',
#   'someone',
#   'go',
#   'fair',
#   'amount',
#   'trouble',
#   'wiki',
#   'paragraph',
#   'certainly',
#   'restore',
#   'copyright',
#   'status',
#   'text',
#   'identify'],
#  ['cut',
#   'intend',
#   'cool',
#   'k',
#   'racialist',
#   'prohibit',
#   'information',
#   'technology',
#   'honest',
#   'goodness',
#   'use',
#   'no',
#   'mean',
#   'anymore',
#   'dickhead'],
#  ['ching',
#   'chong',
#   'permit',
#   'us',
#   'go',
#   'play',
#   'big',
#   'bong',
#   'ping',
#   'pong',
#   'thank',
#   'ok',
#   'bye'],
#  ['god', 'love', 'war', 'women', 'women'],
#  ['value',
#   'bomb',
#   'false',
#   'still',
#   'sorry',
#   'spoil',
#   'fun',
#   'no',
#   'flare',
#   'tamper',
#   'fireworks',
#   'either',
#   'sincerely'],
#  ['one', 'already', 'prove', 'another', 'vagina', 'least', 'crank', 'gas'],
#  ['no', 'girlfriend', 'love', 'fuck', 'muslims'],
#  ['ever', 'go', 'fuck', 'use', 'little', 'fuck', 'bitch'],
#  ['wikipedia', 'think', '।'],
#  ['asshole',
#   'yes',
#   'understand',
#   'whatever',
#   'support',
#   'black',
#   'community',
#   'poor',
#   'white',
#   'community',
#   'leave',
#   'fend',
#   'amount',
#   'jungle',
#   'full',
#   'chimps',
#   'even',
#   'dark',
#   'angry',
#   'ape'],
#  ['michael',
#   'live',
#   'one',
#   'shithole',
#   'commonwealth',
#   'unity',
#   'tell',
#   'wagon',
#   'train'],
#  ['means...', 'go', 'die', '[unk]'],
#  ['muslims', 'need', 'no', 'trouble', 'inbreeding'],
#  ['not',
#   'say',
#   'black',
#   'live',
#   'not',
#   'matter',
#   'live',
#   'truly',
#   'black',
#   'live',
#   'belong',
#   'hearts'],
#  ['awful', 'smell', 'crack', 'acetone'],
#  ['arabs',
#   'appear',
#   'use',
#   'bribe',
#   'threaten',
#   'poor',
#   'result',
#   'try',
#   'bribe',
#   'delegate',
#   'threaten',
#   'war',
#   'assembly',
#   'endorse',
#   'partition',
#   'example',
#   'blood',
#   'flow',
#   'like',
#   'rivers',
#   'middle',
#   'east',
#   'threaten',
#   'western',
#   'power',
#   'oil',
#   'embargo',
#   'abandonment',
#   'realignment',
#   'soviet',
#   'one',
#   'sentence',
#   'modify',
#   'e',
#   'one',
#   'sentence',
#   'stay',
#   'since',
#   'well',
#   'support',
#   'not',
#   'claim',
#   'problem',
#   'besides',
#   'previous',
#   'sentence',
#   'purdue',
#   'give',
#   'much',
#   'weight',
#   'jewish',
#   'pressure'],
#  ['represent',
#   'misunderstand',
#   'genius',
#   'block',
#   'mentally',
#   'retard',
#   'transmidgetards',
#   'hope',
#   'run',
#   'president',
#   'unity',
#   'testament',
#   'able',
#   'fire',
#   'buy',
#   'farm',
#   'heck'],
#  ['stilwater',
#   'place',
#   'deletion',
#   'tag',
#   'article',
#   'stillwater',
#   'need',
#   'clean',
#   'rescue',
#   'not',
#   'delete',
#   'please',
#   'explain',
#   'reason',
#   'behind',
#   'deletion',
#   'tag',
#   'talk',
#   'page'],
#  ['redirect',
#   'talk',
#   'mahatma',
#   'gandhi',
#   'road',
#   'metro',
#   'station',
#   'bangalore'],
#  ['retweet', 'happy', 'break', 'no', 'face', 'blow', 'comment...'],
#  ['since',
#   'get',
#   'mentally',
#   'piss',
#   'play',
#   'beta',
#   'command',
#   'not',
#   'funny',
#   'content',
#   'versus',
#   'normal',
#   'janitors',
#   'whatever',
#   'disrupt',
#   'new',
#   'templates',
#   'like',
#   'feel',
#   'angry',
#   'hurt',
#   'use',
#   'tindersticks',
#   'time',
#   'guess'],
#  ['every',
#   'action',
#   'take',
#   'even',
#   'completely',
#   'unacceptable',
#   'citizen',
#   'contemporary',
#   'societies',
#   'spaniards',
#   'brown',
#   'wreck',
#   'destroy',
#   'interfere',
#   'do'],
#  ['chris',
#   'bias',
#   'claim',
#   'slut',
#   'abusive',
#   'mann',
#   'talk',
#   'page',
#   'not',
#   'true',
#   'ridiculous',
#   'offer',
#   'link',
#   'reason',
#   'mann',
#   'grant',
#   'abusive',
#   'take',
#   'factual',
#   'data',
#   'relevant',
#   'comment',
#   'chriso',
#   'please',
#   'responsible',
#   'truthful',
#   'mature',
#   'already',
#   'note',
#   'many',
#   'comment',
#   'keep',
#   'remove',
#   'facts',
#   'contrary',
#   'beliefs',
#   'wonder',
#   'kim',
#   'hagelstein',
#   'still',
#   'allow',
#   'edit',
#   'remove',
#   'much',
#   'material',
#   'debate',
#   'discussion',
#   'many',
#   'aspects',
#   'agw',
#   'not',
#   'much',
#   'opinion',
#   'data',
#   'principles',
#   'kim',
#   'keep',
#   'remove',
#   'fit',
#   'alarmist',
#   'opinion',
#   'guy',
#   'exhibit',
#   'behavior',
#   'real',
#   'journalism',
#   'would',
#   'ostracize',
#   'disallow',
#   'publications',
#   'soon',
#   'happen',
#   'many',
#   'scientists',
#   'even',
#   'consider',
#   'peer',
#   'review'],
#  ['sheme',
#   'no',
#   'attention',
#   'food',
#   'bank',
#   'police',
#   'pick',
#   'migrant',
#   'interact'],
#  ['foresee',
#   'day',
#   'furor',
#   'humans',
#   'marry',
#   'androids',
#   'robots',
#   'artificial',
#   'persons',
#   'appearance',
#   'indistinguishable',
#   'humans',
#   'whatever',
#   'deal',
#   'gay',
#   'artificial',
#   'persons',
#   'marry',
#   'gay',
#   'humans',
#   'gay',
#   'artificial',
#   'persons',
#   'probably',
#   'lot',
#   'artificial',
#   'dog',
#   'horse',
#   'problems'],
#  ['superman',
#   'original',
#   'series',
#   'pick',
#   'time',
#   'men',
#   'pretty',
#   'good',
#   'graphics'],
#  ['jennifer', 'aniston', 'naked', 'picture', 'hardcore', 'music'],
#  ['retweet',
#   'care',
#   'look',
#   'better',
#   'blue',
#   'ivy',
#   'north',
#   'whatever',
#   'celeb',
#   'baby',
#   'read',
#   'kid',
#   'book',
#   'simply',
#   'bitch'],
#  ['anyone',
#   'bother',
#   'evaluate',
#   'obama',
#   'word',
#   'action',
#   'vs',
#   'someone',
#   'else',
#   'evaluation',
#   'never',
#   'anything',
#   'pragmatic',
#   'centrist',
#   'problem',
#   'position',
#   'extreme',
#   'leave',
#   'claim',
#   'betrayal',
#   'ideology',
#   'never',
#   'subscribe',
#   'extreme',
#   'right',
#   'make',
#   'crystal',
#   'clear',
#   'not',
#   'consider',
#   'liberals',
#   'sub',
#   'human',
#   'criminals',
#   'no',
#   'patience',
#   'moderate',
#   'stripe',
#   'overwhelm',
#   'majority',
#   'people',
#   'middle',
#   'not',
#   'political',
#   'wonks',
#   'not',
#   'time',
#   'necessary',
#   'try',
#   'figure',
#   'truth',
#   'spin',
#   'unfortunately',
#   'leave',
#   'impressions',
#   'whatever',
#   'sensationalist',
#   'press',
#   'last',
#   'get',
#   'attention'],
#  ['mo',
#   'hit',
#   'speedy',
#   'deletion',
#   'mo',
#   'hit',
#   'seem',
#   'purely',
#   'imaginative',
#   'narration',
#   'author',
#   'look',
#   'good',
#   'story',
#   'book',
#   'not',
#   'encyclopedia',
#   'btw',
#   'search',
#   'google',
#   'confirm',
#   'suspicions'],
#  ['autumn', 'idiot', 'flag', 'bearer', 'no', 'step', 'humor'],
#  ['morin',
#   'cern',
#   'thank',
#   'unacceptable',
#   'happen',
#   'morin',
#   'cern',
#   'please',
#   'see',
#   'page',
#   'open',
#   'mabel',
#   'cont',
#   'rib',
#   'thank'],
#  ['laugh',
#   'fuck',
#   'ass',
#   'still',
#   'pull',
#   'hoe',
#   'suppose',
#   'effect',
#   'suppose',
#   'hurt',
#   'fell',
#   'fuck',
#   'boy'],
#  ['get', 'radar', 'come'],
#  ['number',
#   'system',
#   'scholars',
#   'classification',
#   'system',
#   'fairy',
#   'tales',
#   'check',
#   'number',
#   'system',
#   'anti',
#   'marne',
#   'aarne',
#   'thompson',
#   'system',
#   'catalog',
#   'basic',
#   'plot',
#   'countless',
#   'generations',
#   'european',
#   'near',
#   'eastern',
#   'storytellers',
#   'build',
#   'tales',
#   'europeans',
#   'near',
#   'easterners',
#   'travel',
#   'new',
#   'world',
#   'far',
#   'east',
#   'africa',
#   'distant',
#   'place',
#   'tales',
#   'migrate',
#   'well',
#   'often',
#   'flourish',
#   'new',
#   'environments',
#   'hence',
#   'aarne',
#   'thompson',
#   'system',
#   'encompass',
#   'tales',
#   'find',
#   'around',
#   'world',
#   'cinderella',
#   'classify',
#   'see',
#   'cinderella',
#   'rhodes',
#   'yeah',
#   'xian',
#   'rhodopis',
#   'recognize',
#   'older',
#   'yeah',
#   'xian',
#   'hence',
#   'wind',
#   'comment',
#   'unqualified',
#   'misinform',
#   'honestly',
#   'not',
#   'include',
#   'encyclopedia',
#   'mean',
#   'stop',
#   'edit',
#   'article',
#   'regard'],
#  ['add', 'information', 'together', 'reference', 'thank', 'hail'],
#  ['love', 'rude', 'faggot'],
#  ['sir',
#   'due',
#   'respect',
#   'fantastic',
#   'record',
#   'proper',
#   'name',
#   'not',
#   'quite',
#   'proper',
#   'name',
#   'time',
#   'event',
#   'gain',
#   'stature',
#   'history',
#   'become',
#   'proper',
#   'name',
#   'people',
#   'refer',
#   'actually',
#   'challenge',
#   'fact',
#   'even',
#   'though',
#   'wikipedia',
#   'use',
#   'since',
#   'page',
#   'name',
#   'african',
#   'american',
#   'civil',
#   'right',
#   'movement',
#   'variations',
#   'civil',
#   'right',
#   'movement',
#   'not',
#   'proper',
#   'name',
#   'action',
#   'revere',
#   'ah',
#   'mean',
#   'refer',
#   'throughout',
#   'american',
#   'labor',
#   'american',
#   'labor',
#   'historians',
#   'not',
#   'not',
#   'claim',
#   'know',
#   'proper',
#   'common',
#   'real',
#   'name',
#   'include',
#   'define',
#   'example',
#   'pullman',
#   'strike',
#   'african',
#   'american',
#   'civil',
#   'right',
#   'movement',
#   'whatever',
#   'different',
#   'point',
#   'view',
#   'not',
#   'understand',
#   'hey',
#   'make',
#   'us',
#   'human',
#   'advance',
#   'discussions',
#   'think',
#   'section',
#   'head',
#   'survey',
#   'discussion',
#   'not',
#   'define',
#   'section',
#   'try',
#   'not',
#   'mind',
#   'shall',
#   'change',
#   'reflect',
#   'reality',
#   'vote',
#   'utc'],
#  ['care', 'ill', 'make', 'another', 'account', 'stupid', 'wikipedia'],
#  ['stfu',
#   'billion',
#   'mass',
#   'without',
#   'dads',
#   'rich',
#   'bitch',
#   'get',
#   'information',
#   'technology'],
#  ['yeah...', 'bet', 'kill', 'irish', 'fuck', 'nigger'],
#  ['stupid',
#   'somali',
#   'tell',
#   'mogadishu',
#   'bandit',
#   'region',
#   'hell',
#   'whatever',
#   'cannot',
#   'scatter',
#   'refugees',
#   'street',
#   'f',
#   'world',
#   'sudden',
#   'come',
#   'back',
#   'flag',
#   'somalia',
#   'destroy',
#   'capital',
#   'city',
#   'relieve',
#   'face',
#   'relieve',
#   'face',
#   'welcome',
#   'capital',
#   'city',
#   'somaliaflag',
#   'somalia',
#   'blue',
#   'heart',
#   'flag',
#   'somalia',
#   'mogadishu',
#   'not',
#   'bandit'],
#  ['agree',
#   'renter',
#   'no',
#   'set',
#   'official',
#   'source',
#   'criteria',
#   'say',
#   'demo',
#   'album',
#   'therefore',
#   'go',
#   'band',
#   'consider',
#   'release',
#   'band',
#   'work',
#   'allow',
#   'consider',
#   'whatever',
#   'want'],
#  ['go',
#   'bottom',
#   'article',
#   'link',
#   'one',
#   'pack',
#   'org',
#   'describe',
#   'state',
#   'state',
#   'database',
#   'difficult',
#   'give',
#   'simple',
#   'list',
#   'different',
#   'state',
#   'different',
#   'definitions',
#   'conceal',
#   'carry',
#   'not',
#   'include',
#   'reciprocity'],
#  ['thank',
#   'refugees',
#   'country',
#   'deep',
#   'fuck',
#   'debt',
#   'no',
#   'water',
#   'no',
#   'money',
#   'sound',
#   'disaster'],
#  ['vandalism',
#   'whatever',
#   'get',
#   'article',
#   'protect',
#   'not',
#   'familiar',
#   'procedure'],
#  ['retweet',
#   'know',
#   'not',
#   'stupid',
#   'want',
#   'girls',
#   'go',
#   'without',
#   'anyone',
#   'say',
#   'boys',
#   'immature',
#   'tweet',
#   'stuff',
#   'right',
#   'com'],
#  ['hate', 'smell', 'fry', 'egg', 'make', 'sick'],
#  ['smugness',
#   'face',
#   'edit',
#   'page',
#   'add',
#   'correct',
#   'assertion',
#   'well',
#   'know',
#   'smug',
#   'face',
#   'true',
#   'edit',
#   'revert'],
#  ['crud',
#   'everyone',
#   'get',
#   'otherwise',
#   'would',
#   'non',
#   'make',
#   'excuse',
#   'non',
#   'settle',
#   'polish',
#   'whilst',
#   'hang',
#   'multiple',
#   'unlike',
#   'guy'],
#  ['offend', 'way'],
#  ['bang', 'lot', 'travelers', 'feel', 'sorry'],
#  ['suicide',
#   'delegacy',
#   'behave',
#   'not',
#   'put',
#   'workbench',
#   'standup',
#   'justice',
#   'not',
#   'mean',
#   'warp',
#   'sentiency',
#   'judge',
#   'preach',
#   'liberals',
#   'get',
#   'er',
#   'execute'],
#  ['parent', 'beat', 'kid', 'plain', 'bastards'],
#  ['dodo', 'rogue', 'superhero', 'use', 'sex', 'father'],
#  ['non',
#   'insult',
#   'rapscallion',
#   'want',
#   'fry',
#   'chicken',
#   'watermelon',
#   'vine',
#   'orange',
#   'wash',
#   'soda'],
#  ['outrageous',
#   'engage',
#   'no',
#   'edit',
#   'not',
#   'one',
#   'not',
#   'make',
#   'edit',
#   'several',
#   'weeks',
#   'charge',
#   'false',
#   'also',
#   'view',
#   'go',
#   'article',
#   'entirely',
#   'one',
#   'side',
#   'not',
#   'see',
#   'block',
#   'issue',
#   'man',
#   'repeatedly',
#   'use',
#   'mean',
#   'cool',
#   'k',
#   'nothing',
#   'do',
#   'profanity',
#   'use',
#   'woman',
#   'editor',
#   'instead',
#   'block',
#   'complain',
#   'remove',
#   'complaints',
#   'page',
#   'outrageous',
#   'saw',
#   'action',
#   'take',
#   'editor',
#   'side',
#   'npov',
#   'dispute',
#   'wiki',
#   'not',
#   'engage',
#   'edit',
#   'war',
#   'either',
#   'say',
#   'anything',
#   'noteworthy',
#   'anyone',
#   'else',
#   'clearly',
#   'block',
#   'aim',
#   'one',
#   'side',
#   'npov',
#   'dispute',
#   'make',
#   'npov',
#   'situation',
#   'worse',
#   'block',
#   'one',
#   'side',
#   'npov',
#   'dispute',
#   'encourage',
#   'side',
#   'dispute',
#   'remove',
#   'start',
#   'scratch',
#   'essentially',
#   'encourage',
#   'editors',
#   'side',
#   'npov',
#   'dispute',
#   'throw',
#   'hard',
#   'work',
#   'hundreds',
#   'hours',
#   'spend',
#   'research',
#   'write',
#   'article',
#   'article',
#   'even',
#   'one',
#   'side'],
#  ['hello',
#   'welcome',
#   'wikipedia',
#   'thank',
#   'hope',
#   'like',
#   'place',
#   'decide',
#   'stay',
#   'page',
#   'might',
#   'find',
#   'helpful',
#   'five',
#   'pillars',
#   'wikipedia',
#   'tutorial',
#   'edit',
#   'page',
#   'develop',
#   'article',
#   'create',
#   'first',
#   'article',
#   'use',
#   'article',
#   'wizard',
#   'wish',
#   'manual',
#   'style',
#   'hope',
#   'enjoy',
#   'edit',
#   'wikipedia',
#   'please',
#   'sign',
#   'message',
#   'discussion',
#   'page',
#   'use',
#   'four',
#   'tildes',
#   'automatically',
#   'insert',
#   'username',
#   'date',
#   'need',
#   'help',
#   'check',
#   'wikipediaquestions',
#   'ask',
#   'ask',
#   'question',
#   'page',
#   'place',
#   'question',
#   'welcome'],
#  ['thank',
#   'note',
#   'not',
#   'time',
#   'interest',
#   'get',
#   'revert',
#   'restoration',
#   'ism',
#   'thing',
#   'frankly',
#   'bite',
#   'silly',
#   'already',
#   'mention',
#   'wikipedia',
#   'file',
#   'talk',
#   'no',
#   'one',
#   'argue',
#   'honestly',
#   'not',
#   'care',
#   'happy',
#   'give',
#   'input',
#   'really',
#   'anything',
#   'add',
#   'not',
#   'red',
#   'heart',
#   'peace',
#   'symbol',
#   'smile',
#   'faceting',
#   'yang'],
#  ['remove',
#   'offend',
#   'section',
#   'pending',
#   'verifiable',
#   'information',
#   'one'],
#  ['earth',
#   'babble',
#   'mention',
#   'personal',
#   'connection',
#   'definition',
#   'think',
#   'change',
#   'not',
#   'even',
#   'define',
#   'word',
#   'event',
#   'someone',
#   'go',
#   'need',
#   'drop',
#   'ad',
#   'nominees',
#   'listen',
#   'point',
#   'wikipedia',
#   'leeds',
#   'not',
#   'present',
#   'result',
#   'peer',
#   'review',
#   'study',
#   'not',
#   'even',
#   'cite',
#   'peer',
#   'review',
#   'study',
#   'certainly',
#   'not',
#   'case',
#   'absence',
#   'peer',
#   'review',
#   'study',
#   'lead',
#   'acceptable',
#   'instruct',
#   'cite',
#   'characterization',
#   'ptc',
#   'primarily',
#   'censorship',
#   'advocacy',
#   'group',
#   'viewer',
#   'see',
#   'whether',
#   'source',
#   'worth',
#   'credit',
#   'still',
#   'not',
#   'do',
#   'instead',
#   'do',
#   'independent',
#   'research',
#   'edit',
#   'conclusion',
#   'ptc',
#   'arguments',
#   'no',
#   'basis',
#   'already',
#   'violation',
#   'wikipedia',
#   'guidelines',
#   'make',
#   'conclusion',
#   'centerpiece',
#   'article',
#   'intro',
#   'lead',
#   'point',
#   'lead',
#   'objectively',
#   'encapsulate',
#   'topic',
#   'suggest',
#   'lead',
#   'completely',
#   'analogous',
#   'another',
#   'media',
#   'watchdog',
#   'group',
#   'gland',
#   'yet',
#   'give',
#   'no',
#   'basis',
#   'revert',
#   'please',
#   'not',
#   'say',
#   'nonsense',
#   'like',
#   'gland',
#   'support',
#   'policies',
#   'ptc'],
#  ['hi',
#   'hey',
#   'benson',
#   'get',
#   'real',
#   'audience',
#   'hell',
#   'alone',
#   'no',
#   'tell',
#   'mess',
#   'war',
#   'please',
#   'laugh'],
#  ['hey',
#   'liz',
#   'normally',
#   'put',
#   'flag',
#   'office',
#   'country',
#   'youre',
#   'call',
#   'australia',
#   'case',
#   'phone',
#   'not',
#   'meet',
#   'person',
#   'ask',
#   'friend',
#   'brexit'],
#  ['footnote',
#   'placate',
#   'world',
#   'include',
#   'anti',
#   'israel',
#   'jew',
#   'haters',
#   'wikipedia',
#   'believe',
#   'jews',
#   'not',
#   'right',
#   'designate',
#   'capital',
#   'city',
#   'country',
#   'wrong',
#   'course',
#   'though',
#   'try',
#   'correct',
#   'entry',
#   'start',
#   'wikipedia',
#   'version',
#   'anti',
#   'israel',
#   'stone',
#   'throw',
#   'riot'],
#  ['believe',
#   'action',
#   'pure',
#   'vandalism',
#   'either',
#   'base',
#   'pig',
#   'ignorant',
#   'racialism',
#   'pay',
#   'no',
#   'one',
#   'else',
#   'agree',
#   'savor',
#   'information',
#   'technology',
#   'probable',
#   'no',
#   'one',
#   'else',
#   'care',
#   'either',
#   'reduce',
#   'stub',
#   'start',
#   'support',
#   'prejudice',
#   'wiki',
#   'grow',
#   'son',
#   'non',
#   'conversation',
#   'promise',
#   'slut',
#   'ban',
#   'without',
#   'farther',
#   'notice',
#   'please',
#   'not',
#   'give',
#   'notice',
#   'pathetic',
#   'stooge'],
#  ['duo',
#   'create',
#   'whatever',
#   'receive',
#   'reply',
#   'certain',
#   'redux',
#   'write',
#   'user',
#   'apparently',
#   'live',
#   'delusions',
#   'honest',
#   'editor',
#   'peaceful',
#   'behave',
#   'properly',
#   'find',
#   'old',
#   'background',
#   'one',
#   'certain',
#   'user',
#   'apparently',
#   'possessive',
#   'mind',
#   'talkreal',
#   'order',
#   'items'],
#  ['notability',
#   'tag',
#   'place',
#   'request',
#   'speedily',
#   'delete',
#   'wikipedia',
#   'do',
#   'article',
#   'appear',
#   'real',
#   'person',
#   'organization',
#   'band',
#   'club',
#   'company',
#   'etc',
#   'web',
#   'content',
#   'not',
#   'indicate',
#   'subject',
#   'notable',
#   'article',
#   'subject',
#   'include',
#   'encyclopedia',
#   'criteria',
#   'speedy',
#   'deletion',
#   'article',
#   'not',
#   'indicate',
#   'subject',
#   'importance',
#   'significance',
#   'delete',
#   'time',
#   'please',
#   'see',
#   'guidelines',
#   'generally',
#   'accept',
#   'notable',
#   'first',
#   'page',
#   'create',
#   'read',
#   'guide',
#   'write',
#   'first',
#   'article',
#   'think',
#   'assert',
#   'notability',
#   'subject',
#   'contest',
#   'deletion',
#   'add',
#   'top',
#   'page',
#   'exist',
#   'speedy',
#   'deletion',
#   'tag',
#   'couple',
#   'add',
#   'note',
#   'article',
#   'talk',
#   'page',
#   'explain',
#   'position',
#   'aware',
#   'tag',
#   'speedy',
#   'deletion',
#   'article',
#   'meet',
#   'criterion',
#   'delete',
#   'without',
#   'delay',
#   'please',
#   'not',
#   'remove',
#   'speedy',
#   'deletion',
#   'tag',
#   'not',
#   'hesitate',
#   'address',
#   'information',
#   'article',
#   'would',
#   'confirm',
#   'subject',
#   'notability',
#   'wikipedia',
#   'guidelines',
#   'guidelines',
#   'specific',
#   'type',
#   'article',
#   'want',
#   'check',
#   'criteria',
#   'biographies',
#   'websites',
#   'band',
#   'company',
#   'feel',
#   'free',
#   'leave',
#   'note',
#   'talk',
#   'page',
#   'question'],
#  ['word', 'quran', 'prove', 'aim', 'muslim', 'bigots'],
#  ['love', 'fuck'],
#  ['not',
#   'guarantee',
#   'double',
#   'politics',
#   'like',
#   'european',
#   'semitism',
#   'motivate',
#   'us',
#   'single',
#   'black',
#   'intellectual'],
#  ['fail',
#   'answer',
#   'question',
#   'whatever',
#   'know',
#   'slut',
#   'another',
#   'wiki',
#   'editor',
#   'make',
#   'mind',
#   'unrealistic',
#   'assert',
#   'entirely',
#   'unsupported',
#   'well',
#   'course',
#   'not',
#   'slut',
#   'additionally',
#   'even',
#   'slut',
#   'lie',
#   'still',
#   'include',
#   'article',
#   'reliably',
#   'source',
#   'not',
#   'necessarily',
#   'true',
#   'explain',
#   'think',
#   'article',
#   'different',
#   'believe',
#   'personal',
#   'opinion',
#   'alone',
#   'enough',
#   'exclude',
#   'reliably',
#   'source',
#   'information',
#   'article',
#   'please'],
#  ['thank',
#   'joy',
#   'thank',
#   'warm',
#   'welcome',
#   'wikipedia',
#   'msn',
#   'messenger',
#   'aol',
#   'instant',
#   'messenger',
#   'otherwise',
#   'leave',
#   'talk',
#   'page',
#   'please',
#   'like',
#   'wiki',
#   'use',
#   'contact'],
#  ['not',
#   'mention',
#   'fact',
#   'colosseum',
#   'colossus',
#   'build',
#   'slave',
#   'labor',
#   'likely',
#   'africans',
#   'people',
#   'middle',
#   'eastern',
#   'descent',
#   'incredible',
#   'actually',
#   'well'],
#  ['seem', 'merge', 'meantime', 'add', 'link'],
#  ['make',
#   'rather',
#   'not',
#   'see',
#   'fuck',
#   'back',
#   'door',
#   'underhanded',
#   'leave',
#   'hand',
#   'sharia',
#   'code',
#   'implementation',
#   'enforcement',
#   'mudslimes',
#   'laugh',
#   'dirty',
#   'fuck',
#   'asses',
#   'backwards'],
#  ['ref'],
#  ['guess', 'fair', 'man', 'no', 'straw', 'man'],
#  ['wrong'],
#  ['hello',
#   'message',
#   'send',
#   'inform',
#   'currently',
#   'discussion',
#   'wikipediawikiquette',
#   'alert',
#   'regard',
#   'issue',
#   'involve',
#   'thank'],
#  ['muslims', 'muslim', 'terrorists'],
#  ['another', 'fraud', 'senator', 'leave', 'wing'],
#  ['okay',
#   'please',
#   'talk',
#   'please',
#   'talk',
#   'want',
#   'show',
#   'shane',
#   'duffy',
#   'real',
#   'player'],
#  ['bubbly', 'funny'],
#  ['well',
#   'nate',
#   'would',
#   'please',
#   'try',
#   'one',
#   'great',
#   'editions',
#   'understand',
#   'people',
#   'think',
#   'certain',
#   'article',
#   'glad',
#   'not',
#   'one',
#   'know',
#   'problem',
#   'say',
#   'vortex',
#   'morning',
#   'cartoon',
#   'exist',
#   'major',
#   'commercial',
#   'broadcast',
#   'network',
#   'right',
#   'stand',
#   'sunlight',
#   'say',
#   'not',
#   'exist',
#   'nbc',
#   'kid',
#   'cartoon',
#   'one',
#   'show',
#   'mornings',
#   'yeah',
#   'even',
#   'though',
#   'not',
#   'great',
#   'older',
#   'kid',
#   'not',
#   'mean',
#   'morning',
#   'cartoon',
#   'thing',
#   'anymore',
#   'not',
#   'assume',
#   'else',
#   'really',
#   'care',
#   'cannot',
#   'read',
#   'everybody',
#   'mind',
#   'fact',
#   'edit',
#   'good',
#   'faith',
#   'say',
#   'ex',
#   'wife',
#   'friend',
#   'seem',
#   'pretty',
#   'obvious',
#   'psu',
#   'totally',
#   'ignorant',
#   'show',
#   'even',
#   'exist',
#   'not',
#   'television',
#   'service',
#   'give',
#   'look',
#   'prove',
#   'please',
#   'come',
#   'go',
#   'make',
#   'one',
#   'great',
#   'edit',
#   'omm',
#   'like',
#   'vortex',
#   'complete',
#   'indisputable',
#   'source',
#   'either',
#   'like',
#   'exact',
#   'ones',
#   'already',
#   'use',
#   'article',
#   'include',
#   'nbc',
#   'kid',
#   'not',
#   'dispute',
#   'thank',
#   'kindly'],
#  ['would',
#   'love',
#   'brexit',
#   'think',
#   'death',
#   'perfect',
#   'thing',
#   'want',
#   'migrants...'],
#  ['time',
#   'yes',
#   'cheapest',
#   'could',
#   'find',
#   'slut',
#   'slut',
#   'six',
#   'months',
#   'recession',
#   'euro',
#   'slut',
#   'still',
#   'relatively',
#   'expensive',
#   'compare',
#   'dollar',
#   'ship',
#   'would',
#   'effectively',
#   'double',
#   'cost',
#   'well',
#   'recently',
#   'find',
#   'print',
#   'sell',
#   'ship',
#   'us',
#   'free',
#   'order',
#   'also',
#   'buy',
#   'another',
#   'book',
#   'rif',
#   'war',
#   'another',
#   'article',
#   'plan',
#   'edit'],
#  ['burn', 'coal', 'pay', 'income', 'tax'],
#  ['utc',
#   'not',
#   'understand',
#   'question',
#   'mean',
#   'homework',
#   'assignment',
#   'say',
#   'development',
#   'alkaline',
#   'earth',
#   'something',
#   'like',
#   'answer',
#   'depend',
#   'mean',
#   'development',
#   'magnesium',
#   'magnesium',
#   'react',
#   'hot',
#   'water',
#   'liberate',
#   'hydrogen',
#   'do',
#   'precede',
#   'unsigned',
#   'comment',
#   'slut',
#   'add',
#   'moment',
#   'magnesium',
#   'metal',
#   'react',
#   'steam',
#   'hot',
#   'water',
#   'vapor',
#   'boil',
#   'precede',
#   'unsigned',
#   'comment',
#   'slut',
#   'add',
#   'like',
#   'egg',
#   'precede',
#   'unsigned',
#   'comment',
#   'add',
#   'use',
#   'family',
#   'group',
#   'ok',
#   'homework',
#   'need',
#   'know',
#   'use',
#   'alkaline',
#   'earth',
#   'metal',
#   'already',
#   'like',
#   'glass',
#   'really',
#   'not',
#   'enough',
#   'project',
#   'word',
#   'precede',
#   'unsigned',
#   'comment',
#   'slut',
#   'add',
#   'chemistry',
#   'lab',
#   'question',
#   'metallic',
#   'character',
#   'alkaline',
#   'earth',
#   'metal',
#   'increase',
#   'go',
#   'group',
#   'physical',
#   'chemical',
#   'properties',
#   'beryllium',
#   'important',
#   'reactions',
#   'compound',
#   'content',
#   'article',
#   'good',
#   'opinion',
#   'order',
#   'complement',
#   'exist',
#   'information',
#   'think',
#   'would',
#   'good',
#   'idea',
#   'address',
#   'information',
#   'talk',
#   'physical',
#   'chemical',
#   'properties',
#   'elements',
#   'find',
#   'slut',
#   'also',
#   'important',
#   'talk',
#   'beryllium',
#   'since',
#   'mention',
#   'text',
#   'slut',
#   'finally',
#   'decide',
#   'address',
#   'important',
#   'reactions',
#   'compound',
#   'order',
#   'understand',
#   'depth',
#   'alkaline',
#   'earth',
#   'metal',
#   'precede',
#   'unsigned',
#   'comment',
#   'add'],
#  ['reclaim', 'term', 'niggers', 'us', 'us', 'black'],
#  ['obama',
#   'suppose',
#   'communism',
#   'islam',
#   'another',
#   'deadly',
#   'ideology',
#   'not',
#   'race',
#   'suppose',
#   'nazi'],
#  ['utc',
#   'prefer',
#   'set',
#   'not',
#   'know',
#   'whether',
#   'note',
#   'well',
#   'shall',
#   'make',
#   'another',
#   'save',
#   'cook',
#   'islands',
#   'note',
#   'something',
#   'say',
#   'find',
#   'confuse',
#   'though',
#   'quarter',
#   'course',
#   'apply',
#   'decimal',
#   'currency',
#   'no',
#   'good',
#   'deal',
#   'pennies',
#   'shill',
#   'p'],
#  ['happy', 'zoe', 'fridays', 'beatlemania', 'beagles', 'beagle'],
#  ['one',
#   'big',
#   'little',
#   'troglodyte',
#   'bitch',
#   'texts',
#   'first',
#   'man',
#   'friends',
#   'go',
#   'put',
#   'cold',
#   'bullet',
#   'hole',
#   'dig',
#   'knee',
#   'golf',
#   'cap',
#   'let',
#   'fight',
#   'big',
#   'white',
#   'bitch',
#   'dog'],
#  ['retweet',
#   'kat',
#   'fight',
#   'hard',
#   'not',
#   'issue',
#   'exactly',
#   'win',
#   'pathetic',
#   'cheat',
#   'fan',
#   'mr'],
#  ['currently', 'help', 'customer', 'potion', 'help', 'mane', 'loss'],
#  ['stroopwafels',
#   'style',
#   'color',
#   'border',
#   'solid',
#   'style',
#   'align',
#   'middle',
#   'pad',
#   'style',
#   'align',
#   'middle',
#   'pad',
#   'enjoy'],
#  ['go',
#   'ahead',
#   'ban',
#   'interest',
#   'things',
#   'associate',
#   'website',
#   'identify',
#   'promote',
#   'queer',
#   'ban',
#   'queer',
#   'claim',
#   'user',
#   'page',
#   'proud',
#   'marry',
#   'bisexual',
#   'pervert',
#   'sexuality',
#   'own',
#   'encyclopedia',
#   'wikipedia',
#   'financially',
#   'independent',
#   'already',
#   'moral',
#   'bankrupt',
#   'remember',
#   'aid',
#   'kill',
#   'queer'],
#  ['greek',
#   'primacy',
#   'two',
#   'mind',
#   'talk',
#   'page',
#   'discussion',
#   'require',
#   'twice',
#   'blank',
#   'article'],
#  ['sound', 'like', 'plan', 'manner'],
#  ['asian', 'culture', 'not', 'consider', 'backwards'],
#  ['wikibreak',
#   'wiki',
#   'break',
#   'important',
#   'news',
#   'regard',
#   'atlanta',
#   'television',
#   'station',
#   'article',
#   'contrary',
#   'rule',
#   'tv',
#   'vs',
#   'tv',
#   'several',
#   'television',
#   'fan',
#   'wikipedia',
#   'appear',
#   'say',
#   'atlanta',
#   'television',
#   'station',
#   'license',
#   'fcc',
#   'no',
#   'tv',
#   'suffix',
#   'title',
#   'primary',
#   'mean',
#   'call',
#   'sign',
#   'come',
#   'back',
#   'please',
#   'write',
#   'info',
#   'user',
#   'talkie',
#   'regard',
#   'information',
#   'television',
#   'station'],
#  ['retweet',
#   'patriarchy',
#   'trade',
#   'mark',
#   'expel',
#   'pine',
#   'tree',
#   'state',
#   'divulge',
#   'birth',
#   'short',
#   'letter',
#   'save',
#   'copy',
#   'spread',
#   'information',
#   'technology',
#   'like',
#   'nb'],
#  ['also', 'mother', 'prostitute'],
#  ['deletion',
#   'filerichard',
#   'alden',
#   'samuel',
#   'mccloskey',
#   'iii',
#   'mugshot',
#   'jpg',
#   'also',
#   'delete',
#   'link',
#   'image',
#   'note',
#   'deletion',
#   'discussion',
#   'wikipediafiles',
#   'alden',
#   'samuel',
#   'mccloskey',
#   'iii',
#   'mugshot',
#   'jpg',
#   'discussion',
#   'include',
#   'comment',
#   'nominator',
#   'strongly',
#   'disagree',
#   'nomination',
#   'appreciate',
#   'hear',
#   'reason',
#   'deletion'],
#  ['know',
#   'hate',
#   'story',
#   'pure',
#   'hate',
#   'savage',
#   'see',
#   'tweet',
#   'sindh',
#   'mass'],
#  ['seem', 'nice', 'face', 'roll', 'eye'],
#  ['support',
#   'proposer',
#   'per',
#   'wpblpselfpub',
#   'discussion',
#   'would',
#   'pity',
#   'exist',
#   'dispute',
# ...
#   'take'],
#  ['also',
#   'know',
#   'joyce',
#   'kirkconnell',
#   'slut',
#   'bear',
#   'filipino',
#   'descent',
#   'mother',
#   'maiden',
#   'name',
#   'lillian',
#   'ragas',
#   'ragas',
#   'romero',
#   'graduate',
#   'far',
#   'eastern',
#   'university',
#   'philippines',
#   'joyce',
#   'father',
#   'kenneth',
#   'lath',
#   'kirkconnell',
#   'second',
#   'come',
#   'well',
#   'know',
#   'name',
#   'scotland',
#   'father',
#   'us',
#   'veteran',
#   'national',
#   'hero',
#   'thirty',
#   'years',
#   'father',
#   'serve',
#   'unite',
#   'state',
#   'navy',
#   'unite',
#   'state',
#   'army',
#   'joyce',
#   'kirkconnell',
#   'slut',
#   'bear',
#   'texas',
#   'usa',
#   'three',
#   'siblings',
#   'two',
#   'decease',
#   'siblings',
#   'kenneth',
#   'lath',
#   'kirkconnell',
#   'third',
#   'gary',
#   'steven',
#   'kirkconnell',
#   'devon',
#   'stuart',
#   'kirkconnell',
#   'decease',
#   'lillian',
#   'kirkconnell',
#   'decease',
#   'youngest',
#   'amongst',
#   'siblings',
#   'sharon',
#   'leah',
#   'kirkconnell',
#   'joyce',
#   'graduate',
#   'second',
#   'level',
#   'higher',
#   'learn',
#   'philippine',
#   'women',
#   'college',
#   'davao',
#   'city',
#   'philippines',
#   'complete',
#   'minor',
#   'nurse',
#   'subject',
#   'college',
#   'nurse',
#   'stereo',
#   'davao',
#   'university',
#   'philippines',
#   'second',
#   'level',
#   'nurse',
#   'pin',
#   'cap',
#   'slut',
#   'award',
#   'scour',
#   'paul',
#   'hospital',
#   'norfolk',
#   'virginia',
#   'practice',
#   'nurse',
#   'technician',
#   'province',
#   'place',
#   'norfolk',
#   'tandem',
#   'health',
#   'care',
#   'norfolk',
#   'years',
#   'slut',
#   'able',
#   'complete',
#   'nurse',
#   'credentials',
#   'nurse',
#   'department',
#   'medical',
#   'career',
#   'college',
#   'newport',
#   'news',
#   'virginia',
#   'virginia',
#   'beach',
#   'virginia',
#   'graduate',
#   'bachelor',
#   'science',
#   'major',
#   'ally',
#   'health',
#   'online',
#   'education',
#   'ashworth',
#   'university',
#   'georgia',
#   'late',
#   'move',
#   'san',
#   'diego',
#   'california',
#   'continue',
#   'work',
#   'nurse',
#   'support',
#   'sharp',
#   'healthcare',
#   'clinics',
#   'hospitals',
#   'complete',
#   'master',
#   'science',
#   'healthcare',
#   'administration',
#   'ashworth',
#   'university',
#   'distance',
#   'learn',
#   'georgia'],
#  ['quite',
#   'perhaps',
#   'ugliest',
#   'specimen',
#   'male',
#   "e'er",
#   'sober',
#   'gasbag'],
#  ['not',
#   'really',
#   'care',
#   'since',
#   'heather',
#   'still',
#   'smoke',
#   'black',
#   'want',
#   'reach',
#   'around',
#   'come',
#   'face'],
#  ['basically',
#   'fifth',
#   'biggest',
#   'biggest',
#   'know',
#   'whole',
#   'whole',
#   'wikipedia',
#   'want',
#   'not',
#   'vandalize',
#   'go',
#   'right',
#   'ahead',
#   'fifth',
#   'biggest',
#   'know',
#   'whole',
#   'wikipedia',
#   'case',
#   'want',
#   'vandalize',
#   'go',
#   'right',
#   'forward',
#   'ahead'],
#  ['say', 'clara'],
#  ['blog',
#   'website',
#   'ass',
#   'ever',
#   'do',
#   'collegial',
#   'leave',
#   'wiki',
#   'love',
#   'help',
#   'one',
#   'new',
#   'player',
#   'edit',
#   'look',
#   'see',
#   'play',
#   'enforcement',
#   'new',
#   'party',
#   'go',
#   'circle',
#   'jerk',
#   'glue',
#   'eat'],
#  ['cool', 'cold', 'chase', 'hoe', 'victory', 'hand'],
#  ['yah',
#   'manage',
#   'slut',
#   'bitch',
#   'transport',
#   'think',
#   'something',
#   'might',
#   'go',
#   'wrong',
#   'chain',
#   'go',
#   'take',
#   'shop',
#   'later'],
#  ['not',
#   'mention',
#   'shadow',
#   'arm',
#   'liverpool',
#   'museums',
#   'page',
#   'say',
#   'not',
#   'say',
#   'anymore',
#   'table',
#   'spill',
#   'salt',
#   'symbolic',
#   'blood',
#   'later',
#   'spill',
#   'shadow',
#   'arm',
#   'foremost',
#   'brother',
#   'cast',
#   'across',
#   'salt',
#   'thus',
#   'link',
#   'directly',
#   'future',
#   'bloodshed',
#   'uniform',
#   'resource',
#   'locator',
#   'slut',
#   'notice',
#   'new',
#   'page',
#   'shadow',
#   'go',
#   'salt',
#   'symbol',
#   'life',
#   'spill',
#   'table'],
#  ['kiwi', 'people', 'large'],
#  ['name', 'restraint', 'spastic', 'mr'],
#  ['let', 'u', 'verbalise', 'antithesis', 'work', 'stability', 'gay', 'people'],
#  ['leave', 'app', 'article', 'find', 'not', 'neutral'],
#  ['bigger',
#   'sister',
#   'parent',
#   'haunt',
#   'father',
#   'life',
#   'days',
#   'since',
#   'account',
#   'hand',
#   'action',
#   'sister',
#   'daughter',
#   'slut',
#   'murder',
#   'end'],
#  ['coronavirus',
#   'viruses',
#   'cause',
#   'ancient',
#   'chinese',
#   'vile',
#   'negative',
#   'image'],
#  ['super',
#   'bitchy',
#   'not',
#   'say',
#   'whatever',
#   'come',
#   'naturally',
#   'mine',
#   'no',
#   'shame',
#   'filter',
#   'run',
#   'head',
#   'mr'],
#  ['obama',
#   'not',
#   'jackasses',
#   'european',
#   'stop',
#   'report',
#   'lie',
#   'fake',
#   'debate',
#   'like',
#   'scumbags',
#   'mainstream',
#   'media',
#   'not',
#   'cute',
#   'obama',
#   'elect',
#   'refer',
#   'good',
#   'thing',
#   'not',
#   'much',
#   'election',
#   'would',
#   'lose',
#   'fifty',
#   'percent',
#   'vote',
#   'look',
#   'backlash',
#   'tiger',
#   'woods',
#   'publically',
#   'state',
#   'truth',
#   'slut',
#   'not',
#   'headline',
#   'text',
#   'headline',
#   'text',
#   'precede',
#   'unsigned',
#   'comment',
#   'add'],
#  ['delete',
#   'lexington',
#   'list',
#   'already',
#   'feature',
#   'part',
#   'category',
#   'towns',
#   'villages',
#   'viral',
#   'list',
#   'within',
#   'section',
#   'look',
#   'towns',
#   'villages',
#   'viral',
#   'include',
#   'list',
#   'read',
#   'comment',
#   'seem',
#   'compose',
#   'place',
#   'viral',
#   'not',
#   'part',
#   'metropolitan',
#   'borough',
#   'viral',
#   'place',
#   'asstoreton',
#   'part',
#   'metropolitan',
#   'borough',
#   'include',
#   'addendum',
#   'category',
#   'list',
#   'correct',
#   'assumption',
#   'like',
#   'make',
#   'sense',
#   'otherwise',
#   'end',
#   'huge',
#   'list',
#   'place',
#   'name',
#   'article'],
#  ['jews'],
#  ['useless', 'wikipedia'],
#  ['forget',
#   'one',
#   'genseiryu',
#   'butokukai',
#   'result',
#   'interest',
#   'search',
#   'string',
#   'bring',
#   'nippon',
#   'karate',
#   'genseiryu',
#   'butokukai',
#   'denmark',
#   'first',
#   'hit',
#   'website',
#   'yes',
#   'indeed',
#   'mr',
#   'matter',
#   'fact',
#   'think',
#   'agree',
#   'bihar',
#   'maybe',
#   'wikipedia',
#   'indeed',
#   'better',
#   'without',
#   'link',
#   'people',
#   'really',
#   'interest',
#   'genial',
#   'find',
#   'link',
#   'elsewhere',
#   'inside',
#   'outside',
#   'wikipedia',
#   'link',
#   'remove',
#   'not',
#   'put',
#   'link',
#   'back',
#   'stand',
#   'behind',
#   'removal',
#   'long',
#   'still',
#   'page',
#   'description',
#   'must',
#   'correct',
#   'not',
#   'allow',
#   'peter',
#   'lee',
#   'vandalize',
#   'every',
#   'time'],
#  ['say', 'really', 'like', 'cripple', 'still', 'not'],
#  ['retweet',
#   'exactly',
#   'male',
#   'suppose',
#   'protect',
#   'sulkowicz',
#   'scenario',
#   'scot'],
#  ['max',
#   'rfa',
#   'like',
#   'take',
#   'minute',
#   'let',
#   'know',
#   'appreciate',
#   'support',
#   'recently',
#   'close',
#   'rfa',
#   'pass',
#   'count',
#   'support',
#   'opposition',
#   'neutrals',
#   'certainly',
#   'try',
#   'justify',
#   'faith',
#   'use',
#   'tool',
#   'wisely',
#   'happy',
#   'edit',
#   'thank'],
#  ['overlook', 'howe', 'sound'],
#  ['specifically',
#   'find',
#   'time',
#   'link',
#   'www',
#   'oss',
#   'net',
#   'whatever',
#   'post',
#   'someone',
#   'come',
#   'delete',
#   'well',
#   'close',
#   'link',
#   'lead',
#   'work',
#   'others',
#   'protect',
#   'creative',
#   'commons',
#   'license',
#   'persistent',
#   'link',
#   'honorable',
#   'person',
#   'point',
#   'rather',
#   'kidnap',
#   'copy',
#   'document',
#   'able',
#   'educate',
#   'illuminate',
#   'erroneously',
#   'feel',
#   'link',
#   'www',
#   'oss',
#   'net',
#   'self',
#   'promote',
#   'cannot',
#   'afford',
#   'spend',
#   'time',
#   'share',
#   'wealth',
#   'public',
#   'knowledge',
#   'easily',
#   'accessible',
#   'web',
#   'not',
#   'accessible',
#   'via',
#   'wikipedia',
#   'point',
#   'page',
#   'ill',
#   'mannered',
#   'attempt',
#   'deny',
#   'existence',
#   'thousands',
#   'others',
#   'labor',
#   'create',
#   'past',
#   'years'],
#  ['one', 'hate', 'gumption', 'lol'],
#  ['drakes',
#   'new',
#   'shoe',
#   'release',
#   'nike',
#   'jordan',
#   'yes',
#   'glitter',
#   'shoe',
#   'dudes',
#   'fag'],
#  ['subject',
#   'need',
#   'better',
#   'definition',
#   'include',
#   'memoir',
#   'arctica',
#   'algae',
#   'melt',
#   'arctic',
#   'make',
#   'algae',
#   'flourish',
#   'sunlight',
#   'penetrate',
#   'thin',
#   'sea',
#   'ice',
#   'enable',
#   'algal',
#   'growth',
#   'science',
#   'news'],
#  ['evo',
#   'traci',
#   'dan',
#   'c',
#   'bosnia',
#   'along',
#   'best',
#   'dale',
#   'venue',
#   'team',
#   'nazi',
#   'love'],
#  ['please',
#   'not',
#   'vandalize',
#   'page',
#   'edit',
#   'craters',
#   'coccinioides',
#   'continue',
#   'block',
#   'edit',
#   'talk'],
#  ['douchebag',
#   'award',
#   'massive',
#   'penis',
#   'yeezy',
#   'massive',
#   'douchebag',
#   'award'],
#  ['uncle', 'hope', 'like', 'row', 'bullets'],
#  ['beautiful', 'life', 'ching', 'chong', 'long', 'long'],
#  ['plan',
#   'edit',
#   'page',
#   'possible',
#   'coi',
#   'plan',
#   'edit',
#   'page',
#   'less',
#   'advertise',
#   'line',
#   'wikipedia',
#   'policies',
#   'however',
#   'work',
#   'chef',
#   'would',
#   'like',
#   'record',
#   'possible',
#   'coi',
#   'concern',
#   'edit',
#   'unnecessarily',
#   'promotional',
#   'please',
#   'revert',
#   'immediately',
#   'discuss',
#   'talk',
#   'page'],
#  ['delete',
#   'article',
#   'not',
#   'mistake',
#   'no',
#   'one',
#   'mean',
#   'no',
#   'one',
#   'cite',
#   'authority',
#   'acknowledge',
#   'power',
#   'violence',
#   'legitimate',
#   'music',
#   'genre'],
#  ['treba', 'sve', 'track', 'dice'],
#  ['france',
#   'literally',
#   'laws',
#   'render',
#   'anti',
#   'semitism',
#   'illegal',
#   'name',
#   'michael',
#   'jew',
#   'get',
#   'fin',
#   'thousands',
#   'us',
#   'euros',
#   'go',
#   'right',
#   'prison',
#   'lately',
#   'macron',
#   'also',
#   'make',
#   'even',
#   'anti',
#   'zionism',
#   'france',
#   'also',
#   'sometimes',
#   'consider',
#   'anti',
#   'semitism',
#   'france',
#   'consider',
#   'nigger',
#   'infest',
#   'shithole',
#   'run',
#   'kikes'],
#  ['much',
#   'love',
#   'join',
#   'state',
#   'department',
#   'example',
#   'whatsoever',
#   'possess',
#   'sort',
#   'natural',
#   'marvel',
#   'cannot',
#   'encounter',
#   'anywhere',
#   'else',
#   'world',
#   'yellowstone',
#   'grand',
#   'canyon',
#   'many',
#   'amerind'],
#  ['please',
#   'not',
#   'vandalize',
#   'page',
#   'edit',
#   'manuel',
#   'alumni',
#   'continue',
#   'block',
#   'edit'],
#  ['per',
#   'response',
#   'response',
#   'talk',
#   'page',
#   'comment',
#   'not',
#   'answer',
#   'question',
#   'evidence',
#   'continue',
#   'engage',
#   'battleground',
#   'behavior',
#   'apply',
#   'content',
#   'live',
#   'persons',
#   'not',
#   'biographies',
#   'right',
#   'not',
#   'apply',
#   'counterpunch',
#   'magazine',
#   'edit',
#   'unbalance',
#   'article',
#   'feel',
#   'unbalance',
#   'address',
#   'quote',
#   'praise',
#   'magazine',
#   'nothing',
#   'wrong',
#   'put',
#   'blp',
#   'content',
#   'article',
#   'absence',
#   'consensus',
#   'although',
#   'case',
#   'deal',
#   'not',
#   'blp',
#   'issue',
#   'also',
#   'say',
#   'much',
#   'consensus',
#   'inclusion',
#   'content',
#   'no',
#   'consensus',
#   'exclusion',
#   'content',
#   'either',
#   'no',
#   'not',
#   'go',
#   'apologize',
#   'call',
#   'something',
#   'true',
#   'post',
#   'talk',
#   'page',
#   'want',
#   'respond',
#   'although',
#   'let',
#   'know',
#   'not',
#   'matter',
#   'whether',
#   'not',
#   'fellytone',
#   'talk'],
#  ['lesbian', 'gay'],
#  ['make',
#   'deal',
#   'edit',
#   'war',
#   'edit',
#   'okay',
#   'course',
#   'big',
#   'dicks',
#   'fell',
#   'bad',
#   'worst',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'call',
#   'mtv',
#   'around',
#   'way',
#   'lose',
#   'get',
#   'great',
#   'big',
#   'strobe',
#   'not',
#   'cool',
#   'man',
#   'take',
#   'land',
#   'child',
#   'no',
#   'fair',
#   'parent',
#   'people',
#   'care',
#   'understand',
#   'edit',
#   'war',
#   'edit',
#   'okay',
#   'course',
#   'big',
#   'ones',
#   'fell',
#   'bad',
#   'worst',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'promise',
#   'not',
#   'vandal',
#   'anymore',
#   'think',
#   'get',
#   'sore',
#   'vandalize',
#   'anymore',
#   'edit',
#   'war',
#   'edit',
#   'today',
#   'okay',
#   'course',
#   'big',
#   'dicks',
#   'fell',
#   'bad',
#   'worst',
#   'make',
#   'deal',
#   'yeah',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'make',
#   'deal',
#   'make',
#   'deal',
#   'make',
#   'deal',
#   'make',
#   'deal',
#   'make',
#   'deal',
#   'make',
#   'deal',
#   'edit',
#   'war',
#   'edit',
#   'okay',
#   'course',
#   'big',
#   'dicks',
#   'fell',
#   'bad',
#   'worst',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'make',
#   'deal',
#   'yeah',
#   'yeah',
#   'make',
#   'deal',
#   'yeah'],
#  ['marcus', 'cols', 'ton', 'damn', 'trash'],
#  ['evil', 'man', 'would'],
#  ['acs',
#   'match',
#   'list',
#   'bedrock',
#   'cricket',
#   'record',
#   'fact',
#   'people',
#   'choose',
#   'ignore',
#   'certain',
#   'match',
#   'neither',
#   'record',
#   'appear',
#   'widen',
#   'base',
#   'list',
#   'score',
#   'amendments',
#   'important',
#   'wilson',
#   'book',
#   'well',
#   'regard',
#   'historians',
#   'era',
#   'incidentally',
#   'devil',
#   'woodford',
#   'well',
#   'view',
#   'decent',
#   'serious',
#   'novel',
#   'involve',
#   'cricket',
#   'h',
#   'agincourt',
#   'first',
#   'book',
#   'good',
#   'probably',
#   'not',
#   'serious',
#   'book'],
#  ['oh',
#   'strong',
#   'sabine',
#   'ya',
#   'need',
#   'trust',
#   'angel',
#   'moms',
#   'buildthatwall'],
#  ['fuck',
#   'fuck',
#   'hell',
#   'think',
#   'administrator',
#   'power',
#   'hungry',
#   'strike',
#   'not',
#   'mean',
#   'tell',
#   'people',
#   'dumb',
#   'facet',
#   'fuck',
#   'jap',
#   'bitch'],
#  ['hispanics', 'desperate', 'people'],
#  ['landon',
#   'suck',
#   'ask',
#   'birthday',
#   'perform',
#   'beside',
#   'daniel',
#   'recently',
#   'get',
#   'back',
#   'landon',
#   'shitty',
#   'suck'],
#  ['unless',
#   'bitch',
#   'take',
#   'picture',
#   'feature',
#   'bey',
#   'highly',
#   'doubt',
#   'forever',
#   'shut',
#   'mouth',
#   'fuck'],
#  ['good', 'seriously', 'not', 'care', 'thank', 'waste', 'time'],
#  ['filechicken',
#   'tikki',
#   'masala',
#   'vah',
#   'jpg',
#   'list',
#   'deletion',
#   'file',
#   'upload',
#   'alter',
#   'file',
#   'chicken',
#   'tikki',
#   'masala',
#   'vah',
#   'jpg',
#   'list',
#   'wikipediafiles',
#   'deletion',
#   'please',
#   'see',
#   'discussion',
#   'see',
#   'search',
#   'title',
#   'image',
#   'find',
#   'entry',
#   'interest',
#   'not',
#   'delete',
#   'thank',
#   'hi'],
#  ['welcome', 'come', 'intend', 'ace', 'cute'],
#  ['sales',
#   'dil',
#   'sell',
#   'million',
#   'tell',
#   'u',
#   'say',
#   'sell',
#   'million',
#   'record'],
#  ['last',
#   'change',
#   'true',
#   'smiley',
#   'face',
#   'cool',
#   'part',
#   'not',
#   'yeah',
#   'put',
#   'back',
#   'cry',
#   'period'],
#  ['get', 'wommennnnnn', 'evvvvvvviiiiiiil'],
#  ['yes',
#   'love',
#   'aboriginal',
#   'people',
#   'say',
#   'hardworking',
#   'bone',
#   'earth',
#   'tough',
#   'environmentally',
#   'conscious',
#   'well',
#   'love',
#   'know',
#   'not',
#   'mix',
#   'us'],
#  ['never',
#   'find',
#   'cure',
#   'gay',
#   'men',
#   'first',
#   'lock',
#   'cage',
#   'let',
#   'live',
#   'island',
#   'and...'],
#  ['another',
#   'bus',
#   'full',
#   'immigrants',
#   'head',
#   'airport',
#   'deport',
#   'not',
#   'right'],
#  ['talk',
#   'page',
#   'make',
#   'clear',
#   'aboriginal',
#   'activist',
#   'light',
#   'become',
#   'clear',
#   'happy',
#   'article',
#   'ask',
#   'previously',
#   'unengaged',
#   'editors',
#   'review',
#   'article',
#   'pov',
#   'push',
#   'group',
#   'editors',
#   'similar',
#   'political',
#   'view'],
#  ['retweet',
#   'jesus',
#   'turn',
#   'water',
#   'wine',
#   'instagram',
#   'turn',
#   'bust',
#   'bitch',
#   'dim'],
#  ['except',
#   'whatever',
#   'kill',
#   'womb',
#   'birth',
#   'wrong',
#   'rino',
#   'baby',
#   'killer',
#   'murderer',
#   'godless',
#   'gutless',
#   'scot',
#   'scot'],
#  ['would', 'suggest', 'greet', 'foreigners', 'come', 'country'],
#  ['ergo',
#   'neither',
#   'flag',
#   'pa',
#   'palestinian',
#   'territories',
#   'whatever',
#   'mean',
#   'defunct',
#   'british',
#   'protectorate',
#   'therefor',
#   'belong',
#   'un',
#   'neither',
#   'info',
#   'box',
#   'point',
#   'reliable',
#   'source',
#   'back'],
#  ['besides', 'famous', 'gypsies', 'ruin', 'area'],
#  ['tako',
#   'say',
#   'njemacka',
#   'vest',
#   'pa',
#   'great',
#   'rest',
#   'namesake',
#   'nicole',
#   'ajar'],
#  ['ada',
#   'bi',
#   'za',
#   'nest',
#   'la',
#   'not',
#   'po',
#   'ta',
#   'ta',
#   'nee',
#   'nea...',
#   'see',
#   'direct',
#   'osi',
#   'si',
#   'za',
#   'sta',
#   'see',
#   'al',
#   'za',
#   'al',
#   'za',
#   'kosovo',
#   'see',
#   'glacial',
#   'date',
#   'movie',
#   'jet',
#   'normal',
#   'no'],
#  ['read', 'comment', 'yet'],
#  ['dark', 'twist', 'piece', 'shit'],
#  ['jadnici', 'ponds'],
#  ...]

# %%
# from gensim.models import Word2Vec

# model = Word2Vec(sentences, vector_size=300, window=8, min_count=3, workers=4)
# model.save("word2vec.model")

# %%
from gensim.models import Word2Vec
import numpy as np
model = Word2Vec.load("word2vec.model")

def embed_word(text):
    vector_size = model.vector_size
    embeddings = [
        (model.wv[word].astype(np.float32) if word in model.wv else np.zeros(vector_size, dtype=np.float32))
        for word in text
    ]
    
    return embeddings

vs = time.time()
vector_df = processed_df.lazy().with_columns(pl.col("Processed_Content").map_elements(embed_word, return_dtype=pl.List(pl.Array(pl.Float32, 300))).alias("Vector_Content")).collect()
ve = time.time()
print(f"Time taken to train Word2Vec : {(ve-vs):.3f}")

# %%
df_sub = processed_df.slice(1,5)
df_sub
# Out:
# shape: (5, 4)
# ┌──────────────────────────────────┬───────┬────────────────────────────┬──────────────────────────┐
# │ Content                          ┆ Label ┆ Tokens_Content             ┆ Processed_Content        │
# │ ---                              ┆ ---   ┆ ---                        ┆ ---                      │
# │ str                              ┆ i64   ┆ list[str]                  ┆ list[str]                │
# ╞══════════════════════════════════╪═══════╪════════════════════════════╪══════════════════════════╡
# │ the guy next to me just said t…  ┆ 0     ┆ ["the", "guy", … "wtf"]    ┆ ["guy", "next", … "wtf"] │
# │ tell everyone i have zero hatr…  ┆ 0     ┆ ["tell", "everyone", …     ┆ ["tell", "everyone", …   │
# │                                  ┆       ┆ "lying"…                   ┆ "lie"]                   │
# │ okay thanks for writing an awe…  ┆ 0     ┆ ["okay", "thanks", …       ┆ ["okay", "thank", …      │
# │                                  ┆       ┆ "advance"…                 ┆ "advance"]               │
# │ so happy as to not be born hom…  ┆ 1     ┆ ["so", "happy", …          ┆ ["happy", "not", …       │
# │                                  ┆       ┆ "homosexual"…              ┆ "homosexual…             │
# │ jako who so normal had politic…  ┆ 1     ┆ ["jako", "who", … "niece"] ┆ ["jako", "normal", …     │
# │                                  ┆       ┆                            ┆ "niece"]                 │
# └──────────────────────────────────┴───────┴────────────────────────────┴──────────────────────────┘

# %%
vector_df_sub = df_sub.with_columns(pl.col("Processed_Content").map_elements(embed_word, return_dtype=pl.List(pl.Array(pl.Float32, 300))).alias("Vector Content"))

# %%
vector_df_sub
# Out:
# shape: (5, 5)
# ┌──────────────────────┬───────┬──────────────────────┬──────────────────────┬─────────────────────┐
# │ Content              ┆ Label ┆ Tokens_Content       ┆ Processed_Content    ┆ Vector Content      │
# │ ---                  ┆ ---   ┆ ---                  ┆ ---                  ┆ ---                 │
# │ str                  ┆ i64   ┆ list[str]            ┆ list[str]            ┆ list[array[f32,     │
# │                      ┆       ┆                      ┆                      ┆ 300]]               │
# ╞══════════════════════╪═══════╪══════════════════════╪══════════════════════╪═════════════════════╡
# │ the guy next to me   ┆ 0     ┆ ["the", "guy", …     ┆ ["guy", "next", …    ┆ [[-1.667088,        │
# │ just said t…         ┆       ┆ "wtf"]               ┆ "wtf"]               ┆ 0.478226, … -1.36…  │
# │ tell everyone i have ┆ 0     ┆ ["tell", "everyone", ┆ ["tell", "everyone", ┆ [[-0.398947,        │
# │ zero hatr…           ┆       ┆ … "lying"…           ┆ … "lie"]             ┆ 1.735775, … -0.19…  │
# │ okay thanks for      ┆ 0     ┆ ["okay", "thanks", … ┆ ["okay", "thank", …  ┆ [[-0.149784,        │
# │ writing an awe…      ┆       ┆ "advance"…           ┆ "advance"]           ┆ 0.012655, … -0.11…  │
# │ so happy as to not   ┆ 1     ┆ ["so", "happy", …    ┆ ["happy", "not", …   ┆ [[-0.241004,        │
# │ be born hom…         ┆       ┆ "homosexual"…        ┆ "homosexual…         ┆ 1.16751, … -0.413…  │
# │ jako who so normal   ┆ 1     ┆ ["jako", "who", …    ┆ ["jako", "normal", … ┆ [[0.084353,         │
# │ had politic…         ┆       ┆ "niece"]             ┆ "niece"]             ┆ 0.120467, … 0.0733… │
# └──────────────────────┴───────┴──────────────────────┴──────────────────────┴─────────────────────┘

# %%
model.wv["shit"].shape
# Out:
# (300,)
